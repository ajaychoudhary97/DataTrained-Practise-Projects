# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv("C:\\Users\Dell\\Desktop\\happiness_score_dataset.csv")

# %%
dataset.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
#      Loading The data

# %%
dataset.shape
# Out:
# (158, 12)

# %% [markdown]
#     We have 158 rows and 12 Columns in dataset

# %%
dataset.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
#     In these dataset we have no null values

# %%
dataset.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# #    Data Types and Taget Variable

# %% [markdown]
#     We have float type and all independent variable and Happiness Score is our Target Variable

# %% [markdown]
# #      Making DataFrame for the Nominal Data

# %%
dataset_visualization_nominal=dataset[['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']].copy()

# %%
dataset_visualization_nominal.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# #         Visualization of the data

# %% [markdown]
#     For the nominal categorical data will use countplot as it will give the frequency of the classes of the columns:

# %%
import seaborn as sns

# %%
aj = sns.countplot(x="Country", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Country"].value_counts())
# Out:
# Trinidad and Tobago    1
# Djibouti               1
# Lesotho                1
# Congo (Brazzaville)    1
# Mauritania             1
#                       ..
# Madagascar             1
# Angola                 1
# South Korea            1
# Yemen                  1
# Niger                  1
# Name: Country, Length: 158, dtype: int64

# %% [markdown]
#    Visualization The Data

# %%
aj = sns.countplot(x="Region", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Region"].value_counts())
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %% [markdown]
#  In These Visualization Region Column

# %%
aj = sns.countplot(x="Happiness Rank", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Happiness Rank"].value_counts())
# Out:
# 82     2
# 158    1
# 50     1
# 57     1
# 56     1
#       ..
# 106    1
# 105    1
# 104    1
# 103    1
# 1      1
# Name: Happiness Rank, Length: 157, dtype: int64

# %%
aj = sns.countplot(x="Happiness Score", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Happiness Score"].value_counts())
# Out:
# 5.192    2
# 4.642    1
# 5.098    1
# 5.129    1
# 5.889    1
#         ..
# 4.252    1
# 4.633    1
# 3.931    1
# 7.200    1
# 6.750    1
# Name: Happiness Score, Length: 157, dtype: int64

# %% [markdown]
#  It is Our Target Variable

# %%
aj = sns.countplot(x="Standard Error", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Standard Error"].value_counts())
# Out:
# 0.03751    2
# 0.04934    2
# 0.03780    2
# 0.04394    2
# 0.05051    2
#           ..
# 0.09811    1
# 0.05335    1
# 0.05412    1
# 0.06161    1
# 0.02043    1
# Name: Standard Error, Length: 153, dtype: int64

# %%
aj = sns.countplot(x="Economy (GDP per Capita)", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Economy (GDP per Capita)"].value_counts())
# Out:
# 1.30232    1
# 1.12555    1
# 0.93929    1
# 0.39753    1
# 0.28520    1
#           ..
# 1.25018    1
# 1.06098    1
# 0.98549    1
# 1.03192    1
# 0.00000    1
# Name: Economy (GDP per Capita), Length: 158, dtype: int64

# %%
aj = sns.countplot(x="Family", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Family"].value_counts())
# Out:
# 1.18354    1
# 1.12241    1
# 1.02507    1
# 1.11862    1
# 1.26038    1
#           ..
# 1.31379    1
# 0.94632    1
# 1.12447    1
# 1.02626    1
# 0.95152    1
# Name: Family, Length: 158, dtype: int64

# %%
aj = sns.countplot(x="Health (Life Expectancy)", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Health (Life Expectancy)"].value_counts())
# Out:
# 0.92356    2
# 0.41435    1
# 0.81160    1
# 0.51466    1
# 0.80925    1
#           ..
# 0.89533    1
# 0.60820    1
# 0.27688    1
# 0.72521    1
# 0.00000    1
# Name: Health (Life Expectancy), Length: 157, dtype: int64

# %%
aj = sns.countplot(x="Freedom", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Freedom"].value_counts())
# Out:
# 0.41466    1
# 0.36772    1
# 0.40672    1
# 0.43477    1
# 0.31767    1
#           ..
# 0.60362    1
# 0.46611    1
# 0.07699    1
# 0.54210    1
# 0.00000    1
# Name: Freedom, Length: 158, dtype: int64

# %%
aj = sns.countplot(x="Trust (Government Corruption)", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Trust (Government Corruption)"].value_counts())
# Out:
# 0.32524    2
# 0.39928    1
# 0.19317    1
# 0.05327    1
# 0.07122    1
#           ..
# 0.19090    1
# 0.08289    1
# 0.13788    1
# 0.01140    1
# 0.00000    1
# Name: Trust (Government Corruption), Length: 157, dtype: int64

# %%
aj = sns.countplot(x="Generosity", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Generosity"].value_counts())
# Out:
# 0.05444    1
# 0.09131    1
# 0.25328    1
# 0.26475    1
# 0.07172    1
#           ..
# 0.23027    1
# 0.18386    1
# 0.16759    1
# 0.18259    1
# 0.18295    1
# Name: Generosity, Length: 158, dtype: int64

# %%
aj = sns.countplot(x="Dystopia Residual", data=dataset_visualization_nominal)
print(dataset_visualization_nominal["Dystopia Residual"].value_counts())
# Out:
# 2.77729    1
# 2.67585    1
# 1.87996    1
# 1.59927    1
# 3.10712    1
#           ..
# 1.94296    1
# 2.02500    1
# 1.42766    1
# 2.82334    1
# 2.10017    1
# Name: Dystopia Residual, Length: 158, dtype: int64

# %% [markdown]
# #     Encoding The data

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in dataset.columns:
    if dataset[i].dtypes=="object":
        dataset[i]=enc.fit_transform(dataset[i].values.reshape(-1,1))

# %%
dataset
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# #     Describe The dataset:

# %%
dataset.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(dataset.describe(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #              Correlation of the columns with the target columns:

# %%
dataset.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(dataset.corr(),annot=True,linewidths=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
#      Checking the columns which are positively and negative correlated with target columns:

# %%
plt.figure(figsize=(22,7))
dataset.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
dataset.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
#  Keeping +/0.5 as the range for skewness,here are the columns which does not lie within this range
#
#
#         Standard Error-categorical
#         Family-categorical
#         Trust (Government Corruption)-categorical
#         Generosity-categorical
#         Happiness Score-Target variable

# %% [markdown]
# #   Outlier Chek:

# %%
dataset.dtypes
# Out:
# Country                          float64
# Region                           float64
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
#  Checking The outliers on the int and float type of columns.

# %%
dataset['Standard Error'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
dataset['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #   Considering the outlier removal

# %%
dataset.shape
# Out:
# (158, 12)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(dataset))
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
dataset_new_z=dataset[(z<3).all(axis=1)]
dataset_new_z
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
dataset_new_z.shape
# Out:
# (149, 12)

# %%
## percentage loss of data:

# %%
Data_loss=((158-149)/158)*100

# %%
Data_loss
# Out:
# 5.69620253164557

# %% [markdown]
# Loss The data

# %% [markdown]
# Separating the columns into features and Target:

# %%
features=dataset.drop("Happiness Score",axis=1)
target=dataset["Happiness Score"]

# %% [markdown]
# #  Scaling the data using Min-Max Scaler:

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=1)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"At random state {i},the training accuracy is:- {r2_score(target_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is:- {r2_score(target_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is:- 0.9999999444138908
# At random state 0,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 1,the training accuracy is:- 0.9999999444138908
# At random state 1,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 2,the training accuracy is:- 0.9999999444138908
# At random state 2,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 3,the training accuracy is:- 0.9999999444138908
# At random state 3,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 4,the training accuracy is:- 0.9999999444138908
# At random state 4,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 5,the training accuracy is:- 0.9999999444138908
# At random state 5,the testing accuracy is:- 0.9999999394454414
#
#
# At random state 6,the training accuracy is:- 0.9999999444138908
# At random state 6,the testing accuracy is:- 0.9999999394454414
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.9999999439158268

# %% [markdown]
# #    Corss-validation of the model:

# %%
Train_accuracy=r2_score(target_train,pred_train)
Test_accuracy=r2_score(target_test,pred_test)


from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and accuracy score for training is {Train_accuracy} and accuracy for the testing is {Test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.9999997284501867 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# At cross fold 3 the cv score is 0.9999994758122854 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# At cross fold 4 the cv score is 0.9999988371717737 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# At cross fold 5 the cv score is 0.9999982417917263 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# At cross fold 6 the cv score is 0.9999971509064253 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# At cross fold 7 the cv score is 0.99999580182807 and accuracy score for training is -1.1052993512192337 and accuracy for the testing is 0.9999999439158268
#
#
# ...

# %% [markdown]
#   Linear Regression

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test, y=pred_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Actual Score',fontsize=14)
plt.ylabel('Predicted Score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
#       Blue line is Showing The Actual Dataset
#       red Line is Showing The Predication of the data

# %% [markdown]
# #  Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=1, random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss = r2_score(target_test,pred_ls)
lss
# Out:
# 0.9889087963460483

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.42769408750383153

# %% [markdown]
# #    Ensemble Technique:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse', 'mae'],'max_features':["auto", "sqrt", "logo2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf= RandomForestRegressor(criterion="mse",max_features="auto")
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision = rf.predict(features_test)

rfs =r2_score(target_test,pred_decision)
print('R2 Score:',rfs*100)

rfscore = cross_val_score(rf,features,target,cv=5)
rfc =  rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 99.91798612323221
# Cross Val Score: -168.82763749889392

# %%
  We are getting model accuracy as 99.9 %
